# %%
import pandas as pd
pd.set_option('display.max_rows', 60)

import matplotlib.pyplot as plt

# %%
# Having a look at the data
df = pd.read_csv("linkedin_posts.csv", index_col=0)
df
# Out:
#                                                    texts  reactions  comments  \
# index
# 0      Getting in the zone is important for doing qua...          4         0
# 1      AIDACONS - AI & DAta CONSulting; Simple as tha...          9         0
# 2      🗄 Data is the new gold ⭐\n\n\nYou’ve probably ...         17         4
# 3      ⚙ Assessing impact of ML & AI solutions 🤖 \n\n...         12         3
# 4      Want to implement more automation and AI in Yo...         15         4
# 5      Automating LLM fine-tuning on LinkedIn posts! ...         12         0
# 6      Turning Coffee Into Connections! ☕ \n\n\nThis ...         16         4
# 7      How I fine-tuned an LLM to write like me!\n\n\...         18         3
# 8      ⚠ Context Window vs Fine-tuning⚠ \n\n\nI've re...         12         4
# 9      🤖 ML & AI use cases You can utilize right now ...         13         0
# 10     Four things You should do before developing ML...         41         1
# 11     I’ve recently started playing World of Warcraf...         19         3
# 12     🤖 Looking to up your AI game? 🤖 \n\n\n\nLet’s ...         25         1
# 13     Be the positive impact you want to see in the ...         28         2
# 14     💡 The unsexy truth about being a data scientis...         20         1
# 15     🌟 Three mistakes that makes you overestimate m...         17         0
# 16     🚀 The fastest growing startup you’ve never hea...         76         5
# 17     What's the greatest book on human relations? \...          9         3
# 18     🌟 Ever Wondered Why Success Stories on LinkedI...         10         3
# 19     Hey LinkedIn community! 👋 \n\nLooking for a Da...         62         1
# 20     If you’re a Data Scientist, it’s probably time...          7         0
# 21     Want to get started with Supervised Learning i...         15         0
# 22     Proud to be a part of developing the future of...         17         2
# 23     Dear network, recruiters, friends and people o...         50         0
# 24     Do you know about PinPoint - The Future of Tra...          8         0
# 25     We're launching Longship Invest today!\n\nExpe...         23         0
# 26     Next chapter ☀️\n\nA few weeks ago I started a...        108        10
# 27     ⏱ Time for change! ⏱\n\n2023 has had a crazy s...         94        15
# 28     I don’t get why I never heard a thing about pe...         27         3
# 29     Want to be more efficient in data exploration ...         34         2
# 30     Post deployment model monitoring is often negl...         40         5
# 31     Where are the next-generation algorithms for t...         22         2
# 32     Team LeadGenExplosion! 💥\n\nWe are four days i...         58         4
# 33     I’m turning 30 today!\n \nNot that I’m writing...        106         6
# 34     Tools that we use for our ML pipelines 📥 ➡️ 📦 ...         20         2
# 35     Landing your first data science job after fini...         43         4
# 36     Great resources and libraries I have come acro...         50         7
# 37     Data science essentials :\n - Programming lang...         25         1
# 38     We're working quite a bit with explainable mac...         37         6
# 39     Vi klarer den godt i \nhashtag\n#Cyroinvest, s...         10         0
# 40     Hjælp min dygtige og arbejdsomme kæreste Josef...          9         0
# 41     As many have noticed, the Crypto market is ble...         41         1
# 42     We have an open position as Data specialist! 📊...         32         2
# 43     🚀 Hop on board the Risika rocket! 🚀 \n\nWe are...         36         3
# 44     Her kommer en status fra Longship Invest for 2...         11         0
# 45     We're \nhashtag\n#hiring. Know anyone who migh...         10         0
# 46     Longship Invest had a great performance last m...         16         0
# 47     Hvordan udnytter din virksomhed sine overskyde...          2         0
# 48     Cyroinvest står og mangler en jurist/partner. ...          8         0
# 49     Risika is looking for a senior full stack deve...          0         0
# 50                               https://lnkd.in/dYDNc7g          3         0
# 51     Vi har hos Risika haft fremgang i forretningen...         12         0
# 52     Pas på din forretning og dine kunder ! Lav en ...          0         0
# 53     I created this N-body numeric simulation in \n...         16         0
#
#        reposts  impressions
# index
# 0            0          625
# 1            0          985
# 2            1         1479
# 3            0         1116
# 4            0         1396
# 5            0         1332
# 6            0         1497
# 7            0         2204
# 8            0         1392
# 9            0         2199
# 10           2         3135
# 11           0         4385
# 12           0         3093
# 13           1         3098
# 14           0         2463
# 15           0         2327
# 16           4         4490
# 17           0         1264
# 18           0          897
# 19           0         3303
# 20           0          904
# 21           0         2140
# 22           0         1096
# 23           0         1759
# 24           0          691
# 25           0         1721
# 26           0         5444
# 27           0         6521
# 28           0         2913
# 29           0         3210
# 30           1         5266
# 31           0         2025
# 32           0         2559
# 33           0         7273
# 34           0         1757
# 35           0         4536
# 36           1         7074
# 37           0         2006
# 38           0         4458
# 39           0         1471
# 40           0          683
# 41           2         3784
# 42           0         2376
# 43           1         2084
# 44           0          486
# 45           0          867
# 46           0          877
# 47           0          409
# 48           0          570
# 49           0            0
# 50           0            0
# 51           0            0
# 52           0            0
# 53           0            0

# %%
# Add helper column for analysis
df["text_len"] = df["texts"].str.len()

# I'm interested in reach of post (impressions)
eval_metric = "impressions"
df.sort_values(by=eval_metric, ascending=False).head()
# Out:
#                                                    texts  reactions  comments  \
# index
# 33     I’m turning 30 today!\n \nNot that I’m writing...        106         6
# 36     Great resources and libraries I have come acro...         50         7
# 27     ⏱ Time for change! ⏱\n\n2023 has had a crazy s...         94        15
# 26     Next chapter ☀️\n\nA few weeks ago I started a...        108        10
# 30     Post deployment model monitoring is often negl...         40         5
#
#        reposts  impressions  text_len
# index
# 33           0         7273      1660
# 36           1         7074      1132
# 27           0         6521      1248
# 26           0         5444       719
# 30           1         5266       875

# %%
# Look at correlations
df[["reactions", "comments", "reposts", "impressions", "text_len"]].corr()
# Out:
#              reactions  comments   reposts  impressions  text_len
# reactions     1.000000  0.731064  0.321601     0.833986  0.191855
# comments      0.731064  1.000000  0.159323     0.742488  0.270901
# reposts       0.321601  0.159323  1.000000     0.329145  0.158265
# impressions   0.833986  0.742488  0.329145     1.000000  0.301253
# text_len      0.191855  0.270901  0.158265     0.301253  1.000000

# %%
# Simple plot, trying to get a grasp of optimal post lenght
plt.scatter(df["text_len"], df["impressions"])
plt.xlabel("Number of characters")
plt.ylabel("Impressions")
# Out:
# Text(0, 0.5, 'Impressions')

# %%
# Continue analysis with whatever you prefer!
