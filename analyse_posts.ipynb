# %%
import pandas as pd
pd.set_option('display.max_rows', 60)

# %%
df = pd.read_csv("linkedin_posts.csv", index_col=0)
df
# Out:
#                                                    texts  reactions  comments  \
# index
# 0      AIDACONS - AI & DAta CONSulting; Simple as tha...          8         0
# 1      🗄 Data is the new gold ⭐\n\n\nYou’ve probably ...         16         4
# 2      ⚙ Assessing impact of ML & AI solutions 🤖 \n\n...          9         3
# 3      Want to implement more automation and AI in Yo...         15         4
# 4      Automating LLM fine-tuning on LinkedIn posts! ...         10         0
# 5      Turning Coffee Into Connections! ☕ \n\n\nThis ...         16         4
# 6      How I fine-tuned an LLM to write like me!\n\n\...         18         3
# 7      ⚠ Context Window vs Fine-tuning⚠ \n\n\nI've re...         12         4
# 8      🤖 ML & AI use cases You can utilize right now ...         13         0
# 9      Four things You should do before developing ML...         41         1
# 10     I’ve recently started playing World of Warcraf...         19         3
# ...
